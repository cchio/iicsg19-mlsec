# %%
import pickle
import numpy as np

# %%
p = pickle.load(open('waf/trained_waf_model', 'rb'))
# Out:
# /usr/local/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.21.2 when using version 0.21.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.21.2 when using version 0.21.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.21.2 when using version 0.21.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.7/site-packages/sklearn/base.py:306: UserWarning: Trying to unpickle estimator Pipeline from version 0.21.2 when using version 0.21.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
vars(p)
# Out:
# {'steps': [('vectorizer',
#    TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                    dtype=<class 'numpy.float64'>, encoding='utf-8',
#                    input='content', lowercase=True, max_df=1.0, max_features=None,
#                    min_df=0.0, ngram_range=(1, 3), norm='l2', preprocessor=None,
#                    smooth_idf=True, stop_words=None, strip_accents=None,
#                    sublinear_tf=True, token_pattern='(?u)\\b\\w\\w+\\b',
#                    tokenizer=None, use_idf=True, vocabulary=None)),
#   ('classifier', LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                       fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                       max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                       random_state=None, solver='warn', tol=0.0001, verbose=0,
#                       warm_start=False))],
#  'memory': None,
#  'verbose': False}

# %%
vec = p.steps[0][1]
vec
# Out:
# TfidfVectorizer(analyzer='char', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=0.0, ngram_range=(1, 3), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words=None, strip_accents=None,
#                 sublinear_tf=True, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
clf = p.steps[1][1]
clf
# Out:
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#                    fit_intercept=True, intercept_scaling=1, l1_ratio=None,
#                    max_iter=100, multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(vec.idf_)
# Out:
# [ 9.88191796 13.29416517 13.98731235 ... 14.39277746 14.39277746
#  14.39277746]

# %%
print(clf.coef_)
# Out:
# [[4.57756950e+00 2.97557921e-02 1.63383926e-03 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
term_influence = vec.idf_ * clf.coef_
print(term_influence)
# Out:
# [[4.52351662e+01 3.95578415e-01 2.28530201e-02 ... 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]]

# %%
print(np.argpartition(term_influence, 1))
# Out:
# [[81937 92199     2 ... 97829 97830 97831]]

# %%
vec.vocabulary_
# Out:
# {'/': 10522,
#  'z': 94408,
#  'v': 86105,
#  '8': 28882,
#  't': 81489,
#  '7': 27031,
#  'h': 55125,
#  '.': 9860,
#  'k': 61277,
#  's': 79024,
#  'p': 72543,
#  'x': 90144,
#  '?': 35512,
#  '<': 33627,
#  'm': 65680,
#  'e': 48183,
#  'a': 38945,
#  ' ': 348,
#  '-': 8262,
#  'q': 74786,
#  'u': 84107,
#  'i': 57223,
#  '=': 33946,
#  'c': 43527,
#  'o': 70279,
#  'n': 67925,
#  '"': 2477,
#  'w': 88122,
#  '9': 30764,
#  '5': 23159,
#  '2': 17153,
#  '>': 35044,
#  '\n': 154,
#  '/z': 12702,
#  'zv': 96043,
#  'v8': 86654,
#  '8t': 30500,
#  'tv': 83809,
#  'v7': 86616,
#  '7h': 28156,
#  'h8': 55716,
#  '8.': 29065,
#  '.k': 10321,
#  'ks': 62923,
#  'sp': 80882,
#  'px': 74631,
#  'x?': 90924,
#  '?<': 35616,
#  '<m': 33856,
#  'me': 66784,
#  'et': 50386,
#  'ta': 82704,
#  'a ': 38959,
#  ' h': 1328,
#  'ht': 56876,
#  'tt': 83708,
#  'tp': 83490,
#  'p-': 72707,
#  '-e': 8997,
#  'eq': 50203,
#  'qu': 76371,
#  'ui': 85174,
#  'iv': 59168,
#  'v=': 86742,
#  '=s': 34888,
#  'se': 80293,
#  't-': 81820,
#  '-c': 8914,
#  'co': 45180,
#  'oo': 71875,
#  'ok': 71633,
#  'ki': 62444,
#  'ie': 58240,
#  'e ': 48190,
#  ' c': 1134,
#  'on': 71801,
#  'nt': 69906,
#  'te': 82916,
#  'en': 50035,
#  't=': 82461,
#  '="': 33996,
#  '"t': 3104,
#  'es': 50324,
#  'st': 81110,
#  'tc': 82810,
#  'cq': 45281,
#  'qw': 76463,
#  'wz': 90093,
#  'z=': 94960,
#  '=9': 34447,
#  '97': 31388,
#  '75': 27524,
#  '52': 23526,
#  '2"': 17212,
#  '">': 2873,
#  '>\n': 35049,
#  '/zv': 12741,
#  'zv8': 96055,
#  'v8t': 86688,
#  '8tv': 30534,
#  'tv7': 83827,
#  'v7h': 86637,
#  '7h8': 28166,
#  'h8.': 55719,
#  '8.k': 29088,
#  '.ks': 10325,
#  'ksp': 62966,
#  'spx': 80937,
#  'px?': 74652,
#  'x?<': 90928,
#  '?<m': 35621,
#  '<me': 33858,
#  'met': 66839,
#  'eta': 50423,
#  'ta ': 82706,
#  'a h': 38988,
#  ' ht': 1356,
#  'htt': 56920,
#  'ttp': 83749,
#  'tp-': 83499,
#  'p-e': 72724,
#  '-eq': 9029,
#  'equ': 50248,
#  'qui': 76401,
#  'uiv': 85218,
#  'iv=': 59191,
#  'v=s': 86762,
#  '=se': 34898,
#  'set': 80347,
#  'et-': 50400,
#  't-c': 81836,
#  '-co': 8944,
#  'coo': 45219,
#  'ook': 71918,
#  'oki': 71669,
#  'kie': 62472,
#  'ie ': 58242,
#  'e c': 48226,
#  ' co': 1163,
#  'con': 45218,
#  'ont': 71862,
#  'nte': 69945,
#  'ten': 82961,
#  'ent': 50089,
#  'nt=': 69934,
#  't="': 82464,
#  '="t': 34049,
#  '"te': 3109,
#  'tes': 82966,
#  'est': 50378,
#  'stc': 81150,
#  'tcq': 82852,
#  'cqw': 45325,
#  'qwz': 76507,
#  'wz=': 90112,
#  'z=9': 94965,
#  '=97': 34457,
#  '975': 31405,
#  '752': 27540,
#  '52"': 23529,
#  '2">': 17218,
#  '">\n': 2875,
#  'l': 63324,
#  'j': 59431,
#  'b': 41354,
#  '_': 37164,
#  'r': 76641,
#  'g': 52953,
#  'd': 45818,
#  '\\': 36509,
#  '0': 12808,
#  '/e': 11738,
#  'ex': 50609,
#  'xa': 91026,
#  'am': 40565,
#  'mp': 67369,
#  'pl': 73998,
#  'le': 64518,
#  's/': 79373,
#  '/j': 11969,
#  'js': 60895,
#  'p/': 72783,
#  'p2': 72912,
#  '2/': 17397,
#  'x/': 90405,
#  '/w': 12561,
#  'we': 89063,
#  'eb': 49371,
#  'b_': 42159,
#  '_s': 38447,
#  'to': 83431,
#  'or': 72042,
#  're': 77834,
#  'e/': 48555,
#  'e.': 48522,
#  '.c': 10211,
#  'cg': 44765,
#  'gi': 54222,
#  'i?': 57921,
#  '?p': 35902,
#  'pa': 73442,
#  'ag': 40257,
#  'ge': 54011,
#  'e=': 49103,
#  '=.': 34212,
#  '..': 9945,
#  './': 9970,
#  '/.': 10795,
#  'c/': 43793,
#  '/p': 12239,
#  'as': 40902,
#  'ss': 81041,
#  'sw': 81273,
#  'wd': 89004,
#  'd\\': 46763,
#  '\\x': 36814,
#  'x0': 90443,
#  '00': 13152,
#  '0.': 13074,
#  '.h': 10288,
#  'tm': 83332,
#  'ml': 67153,
#  'l\n': 63327,
#  '/ex': 11781,
#  'exa': 50640,
#  'xam': 91060,
#  'amp': 40609,
#  'mpl': 67409,
#  'ple': 74028,
#  'les': 64572,
#  'es/': 50340,
#  's/j': 79411,
#  '/js': 12003,
#  'jsp': 60938,
#  'sp/': 80895,
#  'p/j': 72808,
#  'sp2': 80898,
#  'p2/': 72916,
#  '2/j': 17410,
#  'px/': 74640,
#  'x/w': 90439,
#  '/we': 12583,
#  'web': 89087,
#  'eb_': 49398,
#  'b_s': 42190,
#  '_st': 38483,
#  'sto': 81162,
#  'tor': 83481,
#  'ore': 72080,
#  're/': 77850,
#  'e/w': 48596,
#  're.': 77849,
#  'e.c': 48532,
#  '.cg': 10219,
#  'cgi': 44796,
#  'gi?': 54244,
#  'i?p': 57947,
#  '?pa': 35908,
#  'pag': 73476,
#  'age': 40286,
#  'ge=': 54037,
#  'e=.': 49115,
#  '=..': 34217,
#  '../': 9951,
#  './.': 9974,
#  '/..': 10802,
#  './e': 9981,
#  '/et': 11777,
#  'etc': 50425,
#  'tc/': 82820,
#  'c/p': 43823,
#  '/pa': 12260,
#  'pas': 73488,
#  'ass': 40958,
#  'ssw': 81101,
#  'swd': 81300,
#  'wd\\': 89032,
#  'd\\x': 46769,
#  '\\x0': 36818,
#  'x00': 90449,
#  '00.': 13167,
#  '0.h': 13096,
#  '.ht': 10297,
#  'htm': 56913,
#  'tml': 83366,
#  'ml\n': 67154,
#  'y': 92321,
#  '/c': 11642,
#  'ch': 44815,
#  'he': 56128,
#  'ec': 49425,
#  'ck': 44968,
#  'kb': 62103,
#  'bo': 42919,
#  'ox': 72377,
#  'wa': 88854,
#  'ay': 41231,
#  'y-': 92500,
#  '-b': 8875,
#  'oa': 71111,
#  'ar': 40837,
#  'rd': 77774,
#  'd/': 46155,
#  'd.': 46126,
#  '?d': 35755,
#  'db': 46887,
#  'b=': 42087,
#  '=/': 34224,
#  '0\n': 12811,
#  'p/c': 72801,
#  '/ch': 11673,
#  'che': 44849,
#  'hec': 56155,
#  'eck': 49461,
#  'ckb': 45004,
#  'kbo': 62138,
#  'box': 42966,
#  'ox/': 72391,
#  '/wa': 12579,
#  'way': 88904,
#  'ay-': 41243,
#  'y-b': 92516,
#  '-bo': 8902,
#  'boa': 42943,
#  'oar': 71150,
#  'ard': 40877,
#  'rd/': 77788,
#  'd/w': 46193,
#  'rd.': 77787,
#  'd.c': 46132,
#  'i?d': 57937,
#  '?db': 35761,
#  'db=': 46909,
#  'b=/': 42094,
#  '=/e': 34238,
#  '00\n': 13153,
#  ':': 32669,
#  '1': 14970,
#  '6': 25077,
#  'f': 50796,
#  '3': 19195,
#  '&': 4002,
#  'om': 71740,
#  'po': 74154,
#  'ne': 69117,
#  'ts': 83646,
#  'm_': 66528,
#  '_m': 38212,
#  'mo': 67318,
#  'os': 72103,
#  'pr': 74306,
#  'ra': 77615,
#  'y/': 92571,
#  '/s': 12374,
#  'sc': 80190,
#  'cr': 45330,
#  'ri': 78053,
#  'ip': 58842,
#  'pt': 74414,
#  '/a': 11544,
#  'ad': 40089,
#  'dm': 47446,
#  'mi': 66999,
#  'in': 58725,
#  'n.': 68221,
#  '.p': 10368,
#  'ph': 73803,
#  'hp': 56669,
#  'p?': 73318,
#  '?b': 35712,
#  'ba': 42204,
#  'ed': 49477,
#  'di': 47249,
#  'ir': 58945,
#  'r=': 77452,
#  '=h': 34734,
#  'p:': 73244,
#  ':/': 32759,
#  '//': 10832,
#  '/1': 10954,
#  '19': 15855,
#  '92': 31111,
#  '2.': 17361,
#  '.1': 10019,
#  '16': 15681,
#  '68': 25747,
#  '.2': 10046,
#  '20': 17418,
#  '02': 13274,
#  '.9': 10134,
#  '96': 31332,
#  '6:': 25857,
#  ':8': 32821,
#  '80': 29118,
#  '08': 13599,
#  '0/': 13114,
#  '/t': 12423,
#  'tx': 83912,
#  'xe': 91218,
#  'nj': 69394,
#  'jr': 60847,
#  'rx': 78864,
#  'xf': 91272,
#  'f3': 51193,
#  '3?': 20044,
#  '??': 35641,
#  '?&': 35530,
#  '&c': 4165,
#  'cm': 45080,
#  'md': 66732,
#  'd=': 46686,
#  '=i': 34750,
#  'id': 58174,
#  'd\n': 45830,
#  '/co': 11680,
#  'com': 45217,
#  'omp': 71789,
#  'mpo': 67412,
#  'pon': 74188,
#  'one': 71847,
#  'nen': 69164,
#  'nts': 69959,
#  'ts/': 83663,
#  's/c': 79404,
#  'om_': 71772,
#  'm_m': 66555,
#  '_mo': 38243,
#  'mos': 67360,
#  'osp': 72147,
#  'spr': 80931,
#  'pra': 74331,
#  'ray': 77665,
#  'ay/': 41245,
#  'y/s': 92597,
#  '/sc': 12399,
#  'scr': 80235,
#  'cri': 45365,
#  'rip': 78100,
#  'ipt': 58892,
#  'pts': 74474,
#  's/a': 79402,
#  '/ad': 11572,
#  'adm': 40136,
#  'dmi': 47478,
#  'min': 67038,
#  'in.': 58739,
#  'n.p': 68240,
#  '.ph': 10376,
#  'php': 73840,
#  'hp?': 56695,
#  'p?b': 73336,
#  '?ba': 35715,
#  'bas': 42249,
#  'ase': 40944,
#  'sed': 80331,
#  'edi': 49518,
#  'dir': 47290,
#  'ir=': 58970,
#  'r=h': 77486,
#  '=ht': 34746,
#  'tp:': 83512,
#  'p:/': 73246,
#  '://': 32765,
#  '//1': 10850,
#  '/19': 10972,
#  '192': 15873,
#  '92.': 31122,
#  '2.1': 17364,
#  '.16': 10034,
#  '168': 15705,
#  '68.': 25756,
#  '8.2': 29070,
#  '.20': 10052,
#  '202': 17435,
#  '02.': 13284,
#  '2.9': 17372,
#  '.96': 10141,
#  '96:': 31355,
#  '6:8': 25859,
#  ':80': 32822,
#  '808': 29139,
#  '080': 13611,
#  '80/': 29130,
#  '0/t': 13145,
#  '/tx': 12467,
#  'txe': 83938,
#  'xen': 91258,
#  'enj': 50079,
#  'njr': 69432,
#  'jrx': 60892,
#  'rxf': 78888,
#  'xf3': 91284,
#  'f3?': 51211,
#  '3??': 20050,
#  '??&': 35643,
#  '?&c': 35534,
#  '&cm': 4177,
#  'cmd': 45105,
#  'md=': 66753,
#  'd=i': 46724,
#  '=id': 34757,
#  'id\n': 58176,
#  '(': 5071,
#  ')': 5690,
#  ';': 33026,
#  'eg': 49656,
#  'ga': 53819,
#  'ae': 40151,
#  't5': 82168,
#  '53': 23581,
#  '3a': 20127,
#  'a.': 39228,
#  'm?': 66478,
#  '<i': 33840,
#  'im': 58670,
#  'mg': 66897,
#  'g ': 52965,
#  ' s': 1728,
#  'sr': 80991,
#  'rc': 77717,
#  'c=': 44293,
#  '"j': 3037,
#  'ja': 60022,
#  'av': 41076,
#  'va': 86839,
#  't:': 82371,
#  ':a': 32881,
#  'al': 40504,
#  'er': 50255,
#  'rt': 78647,
#  't(': 81683,
#  '(c': 5460,
#  'ro': 78387,
#  's_': 80037,
#  'si': 80518,
#  'it': 59057,
#  'e_': 49266,
#  'ti': 83135,
#  'ng': 69228,
#  'g.': 53185,
#  '.n': 10348,
#  'na': 68897,
#  'sl': 80673,
#  'l)': 63496,
#  ');': 5964,
#  ';"': 33072,
#  '/eg': 11764,
#  'ega': 49682,
#  'gae': 53843,
#  'aet': 40196,
#  'et5': 50408,
#  't53': 82176,
#  '53a': 23608,
#  '3a.': 20136,
#  'a.h': 39237,
#  'tm?': 83353,
#  'm?<': 66484,
#  '?<i': 35620,
#  '<im': 33846,
#  'img': 58704,
#  'mg ': 66899,
#  'g s': 53005,
#  ' sr': 1765,
#  'src': 81017,
#  'rc=': 77742,
#  'c="': 44296,
#  '="j': 34040,
#  '"ja': 3040,
#  'jav': 60068,
#  'ava': 41103,
#  'vas': 86886,
#  'asc': 40942,
#  'pt:': 74444,
#  't:a': 82392,
#  ':al': 32886,
#  'ale': 40542,
#  'ler': 64571,
#  'ert': 50315,
#  'rt(': 78657,
#  't(c': 81711,
#  '(cr': 5470,
#  'cro': 45371,
#  'ros': 78432,
#  'oss': 72150,
#  'ss_': 81077,
#  's_s': 80072,
#  '_si': 38472,
#  'sit': 80561,
#  'ite': 59097,
#  'te_': 82947,
#  'e_s': 49302,
#  '_sc': 38466,
#  'pti': 74464,
#  'tin': 83173,
#  'ing': 58765,
#  'ng.': 69242,
#  'g.n': 53202,
#  '.na': 10349,
#  'nas': 68943,
#  'asl': 40951,
#  'sl)': 80680,
#  'l);': 63503,
#  ');"': 5969,
#  ';">': 33081,
#  '/d': 11692,
#  'da': 46835,
#  'at': 40966,
#  'ab': 39980,
#  'su': 81176,
#  'ub': 84823,
#  'bs': 43118,
#  'io': 58787,
#  'ns': 69848,
#  'th': 83076,
#  'hu': 56927,
#  'um': 85377,
#  'mb': 66632,
#  'b/': 41580,
#  '/\n': 10528,
#  '/da': 11712,
#  'dat': 46878,
#  'ata': 40998,
#  'tab': 82737,
#  'aba': 40008,
#  'ses': 80346,
#  'esu': 50379,
#  'sub': 81201,
#  'ubs': 84870,
#  'bsc': 43149,
#  'tio': 83174,
#  'ion': 58828,
#  'ons': 71861,
#  'nst': 69898,
#  'sth': 81155,
#  'thu': 83129,
#  'hum': 56961,
#  'umb': 85407,
#  'mb/': 66642,
#  'b/\n': 41581,
#  't/': 81891,
#  'pe': 73644,
#  'ea': 49318,
#  'r.': 76941,
#  '.e': 10250,
#  'e\n': 48184,
#  '/ja': 11985,
#  'pt/': 74433,
#  't/p': 81934,
#  '/pe': 12264,
#  'pea': 73675,
#  'ear': 49362,
#  'ar.': 40853,
#  'r.e': 76949,
#  '.ex': 10263,
#  'exe': 50644,
#  'xe\n': 91219,
#  '%': 3745,
#  '<d': 33817,
#  'v ': 86119,
#  'ty': 83960,
#  'yl': 93665,
#  '"p': 3069,
#  'n:': 68713,
#  'so': 80829,
#  'ol': 71687,
#  'lu': 65374,
#  'ut': 85741,
#  'e;': 49065,
#  ';t': 33539,
#  'op': 71937,
#  ':0': 32773,
#  '0;': 13726,
#  ';l': 33442,
#  'ef': 49600,
#  'ft': 52600,
#  ';w': 33575,
#  'wi': 89260,
#  'dt': 47803,
#  'h:': 55795,
#  ':1': 32789,
#  '10': 15338,
#  '0%': 12888,
#  '%;': 3876,
#  ';h': 33409,
#  'ei': 49758,
#  'ig': 58359,
#  'gh': 54171,
#  '%"': 3761,
#  '" ': 2487,
#  ' o': 1576,
#  'nm': 69549,
#  'ou': 72216,
#  'us': 85679,
#  'eo': 50097,
#  'ov': 72268,
#  've': 87043,
#  '(1': 5268,
#  '1)': 15136,
#  ')"': 5751,
#  'nc': 69001,
#  'cl': 45030,
#  'li': 64732,
#  'ic': 58119,
#  'k=': 61960,
#  '"a': 2962,
#  '>x': 35476,
#  'x<': 90878,
#  '</': 33698,
#  '/b': 11595,
#  'bu': 43227,
#  'n>': 68799,
#  '<di': 33820,
#  'div': 47294,
#  'iv ': 59171,
#  'v s': 86154,
#  ' st': 1767,
#  'sty': 81172,
#  'tyl': 84003,
#  'yle': 93689,
#  'le=': 64546,
#  'e="': 49106,
#  '="p': 34045,
#  '"po': 3074,
#  'pos': 74193,
#  'osi': 72140,
#  'iti': 59101,
#  'on:': 71833,
#  'n:a': 68717,
#  ':ab': 32883,
#  'abs': 40026,
#  'bso': 43161,
#  'sol': 80866,
#  'olu': 71734,
#  'lut': 65415,
#  'ute': 85778,
#  'te;': 82942,
#  'e;t': 49091,
#  ';to': 33554,
#  'top': 83479,
#  'op:': 71960,
#  'p:0': 73247,
#  ':0;': 32784,
#  '0;l': 13744,
#  ';le': 33446,
#  'lef': 64559,
#  'eft': 49648,
#  'ft:': 52622,
#  't:0': 82380,
#  '0;w': 13750,
#  ';wi': 33580,
#  'wid': 89287,
#  'idt': 58230,
#  'dth': 47833,
#  'th:': 83099,
#  'h:1': 55798,
#  ':10': 32792,
#  '100': 15353,
#  '00%': 13158,
#  '0%;': 12899,
#  '%;h': 3878,
#  ';he': 33411,
#  'hei': 56161,
#  'eig': 49791,
#  'igh': 58393,
#  'ght': 54215,
#  'ht:': 56897,
#  't:1': 82381,
#  '0%"': 12890,
#  '%" ': 3763,
#  '" o': 2512,
#  ' on': 1600,
#  'onm': 71855,
#  'nmo': 69588,
#  'mou': 67362,
#  'ous': 72259,
#  'use': 85719,
#  'seo': 80342,
#  'eov': 50144,
#  'ove': 72295,
#  'ver': 87090,
#  'er=': 50288,
#  'r="': 77454,
#  '"pr': 3075,
#  'pro': 74345,
#  'rom': 78426,
#  'mpt': 67417,
#  'pt(': 74426,
#  't(1': 81696,
#  '(1)': 5272,
#  '1)"': 15140,
#  ')" ': 5753,
#  'onc': 71845,
#  'ncl': 69038,
#  'cli': 45062,
#  'lic': 64760,
#  'ick': 58157,
#  'ck=': 44995,
#  'k="': 61963,
#  '="a': 34031,
#  '"al': 2972,
#  ')">': 5763,
#  '">x': 2911,
#  '>x<': 35480,
#  'x</': 90879,
#  '</b': 33707,
#  '/bu': 11636,
#  'but': 43266,
#  'utt': 85793,
#  'tto': 83748,
#  'ton': 83477,
#  'on>': 71837,
#  'n>\n': 68800,
#  "'": 4414,
#  'h_': 55889,
#  '_r': 38408,
#  'ul': 85326,
#  'lt': 65318,
#  's.': 79342,
#  '.d': 10235,
#  'do': 47547,
#  'ot': 72158,
#  't?': 82571,
#  '?s': 35944,
#  '_q': 38374,
#  'ue': 84971,
#  'ry': 78909,
#  'y=': 93012,
#  '=n': 34816,
#  's"': 79122,
#  '><': 35256,
#  '<s': 33886,
#  't>': 82521,
#  '>a': 35356,
#  "('": 5145,
#  "'d": 4868,
#  'ms': 67521,
#  'y_': 93093,
#  '_x': 38654,
#  'xs': 91892,
#  "l'": 63447,
#  "')": 4543,
#  ')<': 6014,
#  '>/': 35216,
#  'p/s': 72816,
#  '/se': 12401,
#  'ess': 50377,
#  'ssi': 81087,
#  'sio': 80556,
#  'nss': 69897,
#  'sse': 81083,
#  'sea': 80328,
#  'arc': 40876,
#  'rch': 77755,
#  'ch_': 44844,
#  'h_r': 55920,
#  '_re': 38426,
#  'res': 77888,
#  'sul': 81211,
#  'ult': 85370,
#  'lts': 65365,
#  'ts.': 83662,
#  's.d': 79350,
#  '.do': 10243,
#  'dot': 47592,
#  'ot?': 72185,
#  't?s': 82599,
#  '?se': 35952,
#  'h_q': 55919,
#  '_qu': 38402,
#  'que': 76397,
#  'uer': 85020,
#  'ery': 50320,
#  'ry=': 78932,
#  'y=n': 93043,
#  '=ne': 34821,
#  'nes': 69169,
#  'ssu': 81099,
#  'sus': 81218,
#  'us"': 85683,
#  's">': 79132,
#  '"><': 2886,
#  '><s': 35288,
#  '<sc': 33893,
#  'pt>': 74448,
#  't>a': 82550,
#  '>al': 35364,
#  "t('": 81690,
#  "('d": 5166,
#  "'do": 4875,
#  'otc': 72192,
#  'tcm': 82848,
#  'cms': 45120,
#  'ms_': 67546,
#  '_se': 38468,
#  'ry_': 78936,
#  'y_x': 93131,
#  '_xs': 38685,
#  'xss': 91935,
#  'ss.': 81056,
#  's.n': 79360,
#  "sl'": 80679,
#  "l')": 63451,
#  "')<": 4558,
#  ')</': 6021,
#  '</s': 33720,
#  't>/': 82537,
#  '>/\n': 35217,
#  ',': 7838,
#  '*': 6910,
#  '1\n': 14976,
#  '\nu': 259,
#  'un': 85433,
#  'ni': 69339,
#  'n\n': 67928,
#  '\ns': 251,
#  'el': 49915,
#  'ct': 45438,
#  't\n': 81498,
#  '\n1': 194,
#  '1,': 15201,
#  ',2': 8001,
#  '2,': 17302,
#  ',3': 8015,
#  '3/': 19429,
#  '/*': 10706,
#  '*\n': 6914,
#  '1\nu': 14977,
#  '\nun': 260,
#  'uni': 85462,
#  'nio': 69381,
#  'on\n': 71803,
#  'n\ns': 67932,
#  '\nse': 253,
#  'sel': 80339,
#  'ele': 49951,
#  'lec': 64556,
#  'ect': 49470,
#  'ct\n': 45440,
#  't\n1': 81502,
#  '\n1,': 195,
#  '1,2': 15208,
#  ',2,': 8003,
#  '2,3': 17309,
#  ',3/': 8021,
#  '3/*': 19433,
#  '/*\n': 10708,
#  '/o': 12195,
#  'vc': 86942,
#  'i/': 57459,
#  'la': 64307,
#  'rm': 78271,
#  'm.': 65928,
#  'e?': 49191,
#  '?o': 35892,
#  'bv': 43273,
#  'rb': 77669,
#  '=1': 34280,
#  '/ov': 12234,
#  'ovc': 72293,
#  'vcg': 86972,
#  'gi/': 54233,
#  'i/o': 57485,
#  'ova': 72291,
#  'val': 86879,
#  'ala': 40538,
#  'lar': 64356,
#  'arm': 40886,
#  'rm.': 78286,
#  'm.e': 65935,
#  'xe?': 91241,
#  'e?o': 49212,
#  '?ov': 35901,
#  'vab': 86869,
#  'abv': 40029,
#  'bve': 43297,
#  'erb': 50297,
#  'rbo': 77705,
#  'bos': 42961,
#  'ose': 72136,
#  'se=': 80320,
#  'e=1': 49118,
#  '=1\n': 34281,
#  '+': 7199,
#  ')+': 5862,
#  '+w': 7795,
#  'ai': 40362,
#  'tf': 82974,
#  'fo': 52345,
#  'r+': 76865,
#  '+d': 7602,
#  'de': 47041,
#  'y+': 92473,
#  "+'": 7256,
#  "'0": 4643,
#  '0:': 13712,
#  '05': 13435,
#  "5'": 23249,
#  "'\n": 4417,
#  "')+": 4551,
#  ')+w': 5884,
#  ...}

# %%
# First, we create a token vocabulary dictionary so that
# we can access tokens by index.
vocab = dict([(v,k) for k,v in vec.vocabulary_.items()])

# %%
term_idx = np.argpartition(term_influence, 1)[0][0]

# %%
print(vocab[term_idx])
# Out:
# t/s

# %%
payload = "<script>alert(1)</script>"

# %%
p.predict([payload])[0]
# Out:
# 1

# %%
p.predict_proba([payload])[0]
# Out:
# array([1.97308325e-09, 9.99999998e-01])

# %%
p.predict_proba([payload + '/' + vocab[term_idx]])[0]
# Out:
# array([1.78268832e-07, 9.99999822e-01])

# %%
p.predict_proba([payload + '/' + vocab[term_idx]*258])[0]
# Out:
# array([0.49960184, 0.50039816])

# %%
p.predict([payload + '/' + vocab[term_idx]*258])[0]
# Out:
# 1

# %%
print(payload + '/' + vocab[term_idx]*258)
# Out:
# <script>alert(1)</script>...
